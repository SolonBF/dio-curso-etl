# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BEL�M
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                    0                    N�O
# 1                    0                    N�O
# 2                    0                    N�O
# 3                    0                    N�O
# 4                    0                    N�O

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BEL�M'

# %%
df.loc[3]
# Out:
# codigo_ocorrencia2                        39527
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade            LUCAS DO RIO VERDE
# ocorrencia_uf                                MT
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-04 00:00:00
# ocorrencia_hora                        17:30:00
# total_recomendacoes                           0
# ocorrencia_saida_pista                      N�O
# Name: 3, dtype: object

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 1               40349                INCIDENTE               BEL�M
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 1                    0                    N�O
# 2                    0                    N�O
# 3                    0                    N�O

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 10               39789                INCIDENTE  S�O PEDRO DO SUL
# 40               39158                INCIDENTE             BEL�M
#
#    ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 10            RS                 ****     2010-01-10        21:30:00
# 40            PA                 ****     2010-01-28        16:00:00
#
#     total_recomendacoes ocorrencia_saida_pista
# 10                    0                    N�O
# 40                    0                    N�O

# %%
df.loc[:]
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BEL�M
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5746               79804                INCIDENTE            CAMPINAS
# 5747               79757          INCIDENTE GRAVE   LAGOA DA CONFUS�O
# 5748               79802                INCIDENTE      RIO DE JANEIRO
# 5749               79756          INCIDENTE GRAVE           VICENTINA
# 5750               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RJ                 ****     2010-01-03        12:00:00
# 1               PA                 SBBE     2010-01-03        11:05:00
# 2               RJ                 SBRJ     2010-01-03        03:00:00
# 3               MT                 ****     2010-01-04        17:30:00
# 4               RS                 SBPK     2010-01-05        19:25:00
# ...            ...                  ...            ...             ...
# 5746            SP                 SBKP     2020-12-29        19:00:00
# 5747            TO                 ****     2020-12-30        18:30:00
# 5748            RJ                 SBGL     2020-12-30        00:54:00
# 5749            MS                 ****     2020-12-31        09:00:00
# 5750            RJ                 SBJR     2020-12-31        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                       0                    N�O
# 1                       0                    N�O
# 2                       0                    N�O
# 3                       0                    N�O
# 4                       0                    N�O
# ...                   ...                    ...
# 5746                    0                    N�O
# 5747                    0                    N�O
# 5748                    0                    N�O
# 5749                    0                    N�O
# 5750                    0                    N�O
#
# [5751 rows x 9 columns]

# %%
df.codigo_ocorrencia2.is_unique
# Out:
# True

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BEL�M
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                    0                    N�O
# 1                    0                    N�O
# 2                    0                    N�O
# 3                    0                    N�O
# 4                    0                    N�O

# %%
df.set_index('codigo_ocorrencia2', inplace=True)

# %%
df.head()
# Out:
#                    ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia2
# 40211                             INCIDENTE      RIO DE JANEIRO            RJ
# 40349                             INCIDENTE               BEL�M            PA
# 40351                             INCIDENTE      RIO DE JANEIRO            RJ
# 39527                              ACIDENTE  LUCAS DO RIO VERDE            MT
# 40324                             INCIDENTE             PELOTAS            RS
#
#                    ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia2
# 40211                              ****     2010-01-03        12:00:00
# 40349                              SBBE     2010-01-03        11:05:00
# 40351                              SBRJ     2010-01-03        03:00:00
# 39527                              ****     2010-01-04        17:30:00
# 40324                              SBPK     2010-01-05        19:25:00
#
#                     total_recomendacoes ocorrencia_saida_pista
# codigo_ocorrencia2
# 40211                                 0                    N�O
# 40349                                 0                    N�O
# 40351                                 0                    N�O
# 39527                                 0                    N�O
# 40324                                 0                    N�O

# %%
df.loc[39527]
# Out:
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade            LUCAS DO RIO VERDE
# ocorrencia_uf                                MT
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-04 00:00:00
# ocorrencia_hora                        17:30:00
# total_recomendacoes                           0
# ocorrencia_saida_pista                      N�O
# Name: 39527, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                INCIDENTE               BEL�M            PA
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                 ****     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 ****     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0
#
#   ocorrencia_saida_pista
# 0                    N�O
# 1                    N�O
# 2                    N�O
# 3                    N�O
# 4                    N�O

# %%
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#   ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE    RIO DE JANEIRO            RJ
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                          2010-01-03        12:00:00                    0
#
#   ocorrencia_saida_pista
# 0                    N�O

# %%
df.loc[1] = 20

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 ****  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                    0                    N�O
# 1                   20                     20
# 2                    0                    N�O
# 3                    0                    N�O
# 4                    0                    N�O

# %%
df.loc[:, 'total_recomendacoes'] = 10

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 ****  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                   10                    N�O
# 1                   10                     20
# 2                   10                    N�O
# 3                   10                    N�O
# 4                   10                    N�O

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'Grave'

# %%
df
# Out:
#      ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      RIO DE JANEIRO            RJ
# 1                          20                  20            20
# 2                   INCIDENTE      RIO DE JANEIRO            RJ
# 3                    ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                   INCIDENTE             PELOTAS            RS
# ...                       ...                 ...           ...
# 5746                    Grave            CAMPINAS            SP
# 5747          INCIDENTE GRAVE   LAGOA DA CONFUS�O            TO
# 5748                INCIDENTE      RIO DE JANEIRO            RJ
# 5749          INCIDENTE GRAVE           VICENTINA            MS
# 5750                INCIDENTE      RIO DE JANEIRO            RJ
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                          2010-01-03 00:00:00        12:00:00
# 1                      20                   20              20
# 2                    SBRJ  2010-01-03 00:00:00        03:00:00
# 3                    ****  2010-01-04 00:00:00        17:30:00
# 4                    SBPK  2010-01-05 00:00:00        19:25:00
# ...                   ...                  ...             ...
# 5746                 SBKP  2020-12-29 00:00:00        19:00:00
# 5747                 ****  2020-12-30 00:00:00        18:30:00
# 5748                 SBGL  2020-12-30 00:00:00        00:54:00
# 5749                 ****  2020-12-31 00:00:00        09:00:00
# 5750                 SBJR  2020-12-31 00:00:00        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                      10                    N�O
# 1                      10                     20
# 2                      10                    N�O
# 3                      10                    N�O
# 4                      10                    N�O
# ...                   ...                    ...
# 5746                   10                    N�O
# 5747                   10                    N�O
# 5748                   10                    N�O
# 5749                   10                    N�O
# 5750                   10                    N�O
#
# [5751 rows x 8 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 11                      Grave         S�O PAULO            SP
# 16                      Grave         S�O PAULO            SP
# 18                      Grave            SANTOS            SP
# 26                      Grave          SOROCABA            SP
# 27                      Grave          CAMPINAS            SP
# ...                       ...               ...           ...
# 5703                    Grave         S�O PAULO            SP
# 5704                    Grave          SOROCABA            SP
# 5714                    Grave         S�O PAULO            SP
# 5741                    Grave         S�O PAULO            SP
# 5746                    Grave          CAMPINAS            SP
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 11                   SBMT  2010-01-10 00:00:00        14:50:00
# 16                   ****  2010-01-15 00:00:00        15:00:00
# 18                   ****  2010-01-15 00:00:00        17:45:00
# 26                   ****  2010-01-20 00:00:00        13:10:00
# 27                   ****  2010-01-21 00:00:00        20:45:00
# ...                   ...                  ...             ...
# 5703                 SBSP  2020-12-03 00:00:00        14:42:00
# 5704                 SDCO  2020-12-04 00:00:00        15:30:00
# 5714                 SBMT  2020-12-11 00:00:00        13:50:00
# 5741                 SBMT  2020-12-28 00:00:00        10:15:00
# 5746                 SBKP  2020-12-29 00:00:00        19:00:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 11                     10                    N�O
# 16                     10                    N�O
# 18                     10                    N�O
# 26                     10                    N�O
# 27                     10                    N�O
# ...                   ...                    ...
# 5703                   10                    N�O
# 5704                   10                    N�O
# 5714                   10                    SIM
# 5741                   10                    N�O
# 5746                   10                    N�O
#
# [1373 rows x 8 columns]

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 ****  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                   10                    N�O
# 1                   10                     20
# 2                   10                    N�O
# 3                   10                    N�O
# 4                   10                    N�O

# %%
df.loc[df.ocorrencia_aerodromo == '*****', ['ocorrencia_aerodromo']] == pd.NA
# Out:
#       ocorrencia_aerodromo
# 433                  False
# 4064                 False
# 4365                 False
# 4650                 False
# 4809                 False
# ...                    ...
# 5603                 False
# 5620                 False
# 5683                 False
# 5686                 False
# 5721                 False
#
# [149 rows x 1 columns]

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 ****  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                   10                    N�O
# 1                   10                     20
# 2                   10                    N�O
# 3                   10                    N�O
# 4                   10                    N�O

# %%
df.replace(['**','###!', '####', '****', '*****', ' '], pd.NA, inplace=True)

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 <NA>  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                   10                    N�O
# 1                   10                     20
# 2                   10                    N�O
# 3                   10                    N�O
# 4                   10                    N�O

# %%
df.tail()
# Out:
#      ocorrencia_classificacao  ocorrencia_cidade ocorrencia_uf  \
# 5746                    Grave           CAMPINAS            SP
# 5747          INCIDENTE GRAVE  LAGOA DA CONFUS�O            TO
# 5748                INCIDENTE     RIO DE JANEIRO            RJ
# 5749          INCIDENTE GRAVE          VICENTINA            MS
# 5750                INCIDENTE     RIO DE JANEIRO            RJ
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 5746                 SBKP  2020-12-29 00:00:00        19:00:00
# 5747                 <NA>  2020-12-30 00:00:00        18:30:00
# 5748                 SBGL  2020-12-30 00:00:00        00:54:00
# 5749                 <NA>  2020-12-31 00:00:00        09:00:00
# 5750                 SBJR  2020-12-31 00:00:00        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 5746                   10                    N�O
# 5747                   10                    N�O
# 5748                   10                    N�O
# 5749                   10                    N�O
# 5750                   10                    N�O

# %%
df.isna().sum()
# Out:
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2347
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# ocorrencia_saida_pista         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2347
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# ocorrencia_saida_pista         0
# dtype: int64

# %%
df.fillna(10, inplace=True)

# %%
df.isnull().sum()
# Out:
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# ocorrencia_saida_pista      0
# dtype: int64

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                   10  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                   10                    N�O
# 1                   10                     20
# 2                   10                    N�O
# 3                   10                    N�O
# 4                   10                    N�O

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2347
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes         5751
# ocorrencia_saida_pista         0
# dtype: int64

# %%
df.fillna(value= {'total_recomendacoes': 10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2347
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# ocorrencia_saida_pista         0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 <NA>  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista  total_recomendacoes_bkp
# 0                   10                    N�O                       10
# 1                   10                     20                       10
# 2                   10                    N�O                       10
# 3                   10                    N�O                       10
# 4                   10                    N�O                       10

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                       20                  20            20
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                       2010-01-03 00:00:00        12:00:00
# 1                   20                   20              20
# 2                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3                 <NA>  2010-01-04 00:00:00        17:30:00
# 4                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_saida_pista
# 0                   10                    N�O
# 1                   10                     20
# 2                   10                    N�O
# 3                   10                    N�O
# 4                   10                    N�O

# %%
df.dropna()
# Out:
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE    RIO DE JANEIRO            RJ
# 1                          20                20            20
# 2                   INCIDENTE    RIO DE JANEIRO            RJ
# 4                   INCIDENTE           PELOTAS            RS
# 6                   INCIDENTE             COARI            AM
# ...                       ...               ...           ...
# 5742                 ACIDENTE     RIO PARANA�BA            MG
# 5745          INCIDENTE GRAVE     MANOEL URBANO            AC
# 5746                    Grave          CAMPINAS            SP
# 5748                INCIDENTE    RIO DE JANEIRO            RJ
# 5750                INCIDENTE    RIO DE JANEIRO            RJ
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                          2010-01-03 00:00:00        12:00:00
# 1                      20                   20              20
# 2                    SBRJ  2010-01-03 00:00:00        03:00:00
# 4                    SBPK  2010-01-05 00:00:00        19:25:00
# 6                    SBUY  2010-01-07 00:00:00        18:40:00
# ...                   ...                  ...             ...
# 5742                 SNRP  2020-12-28 00:00:00        17:00:00
# 5745                 SIMB  2020-12-29 00:00:00        18:30:00
# 5746                 SBKP  2020-12-29 00:00:00        19:00:00
# 5748                 SBGL  2020-12-30 00:00:00        00:54:00
# 5750                 SBJR  2020-12-31 00:00:00        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                      10                    N�O
# 1                      10                     20
# 2                      10                    N�O
# 4                      10                    N�O
# 6                      10                    SIM
# ...                   ...                    ...
# 5742                   10                    N�O
# 5745                   10                    SIM
# 5746                   10                    N�O
# 5748                   10                    N�O
# 5750                   10                    N�O
#
# [3404 rows x 8 columns]

# %%
df
# Out:
#      ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      RIO DE JANEIRO            RJ
# 1                          20                  20            20
# 2                   INCIDENTE      RIO DE JANEIRO            RJ
# 3                    ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                   INCIDENTE             PELOTAS            RS
# ...                       ...                 ...           ...
# 5746                    Grave            CAMPINAS            SP
# 5747          INCIDENTE GRAVE   LAGOA DA CONFUS�O            TO
# 5748                INCIDENTE      RIO DE JANEIRO            RJ
# 5749          INCIDENTE GRAVE           VICENTINA            MS
# 5750                INCIDENTE      RIO DE JANEIRO            RJ
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                          2010-01-03 00:00:00        12:00:00
# 1                      20                   20              20
# 2                    SBRJ  2010-01-03 00:00:00        03:00:00
# 3                    <NA>  2010-01-04 00:00:00        17:30:00
# 4                    SBPK  2010-01-05 00:00:00        19:25:00
# ...                   ...                  ...             ...
# 5746                 SBKP  2020-12-29 00:00:00        19:00:00
# 5747                 <NA>  2020-12-30 00:00:00        18:30:00
# 5748                 SBGL  2020-12-30 00:00:00        00:54:00
# 5749                 <NA>  2020-12-31 00:00:00        09:00:00
# 5750                 SBJR  2020-12-31 00:00:00        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                      10                    N�O
# 1                      10                     20
# 2                      10                    N�O
# 3                      10                    N�O
# 4                      10                    N�O
# ...                   ...                    ...
# 5746                   10                    N�O
# 5747                   10                    N�O
# 5748                   10                    N�O
# 5749                   10                    N�O
# 5750                   10                    N�O
#
# [5751 rows x 8 columns]

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#      ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      RIO DE JANEIRO            RJ
# 1                          20                  20            20
# 2                   INCIDENTE      RIO DE JANEIRO            RJ
# 3                    ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                   INCIDENTE             PELOTAS            RS
# ...                       ...                 ...           ...
# 5746                    Grave            CAMPINAS            SP
# 5747          INCIDENTE GRAVE   LAGOA DA CONFUS�O            TO
# 5748                INCIDENTE      RIO DE JANEIRO            RJ
# 5749          INCIDENTE GRAVE           VICENTINA            MS
# 5750                INCIDENTE      RIO DE JANEIRO            RJ
#
#      ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                          2010-01-03 00:00:00        12:00:00
# 1                      20                   20              20
# 2                    SBRJ  2010-01-03 00:00:00        03:00:00
# 3                    <NA>  2010-01-04 00:00:00        17:30:00
# 4                    SBPK  2010-01-05 00:00:00        19:25:00
# ...                   ...                  ...             ...
# 5746                 SBKP  2020-12-29 00:00:00        19:00:00
# 5747                 <NA>  2020-12-30 00:00:00        18:30:00
# 5748                 SBGL  2020-12-30 00:00:00        00:54:00
# 5749                 <NA>  2020-12-31 00:00:00        09:00:00
# 5750                 SBJR  2020-12-31 00:00:00        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                      10                    N�O
# 1                      10                     20
# 2                      10                    N�O
# 3                      10                    N�O
# 4                      10                    N�O
# ...                   ...                    ...
# 5746                   10                    N�O
# 5747                   10                    N�O
# 5748                   10                    N�O
# 5749                   10                    N�O
# 5750                   10                    N�O
#
# [5750 rows x 8 columns]

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BEL�M
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79757          INCIDENTE GRAVE   LAGOA DA CONFUS�O
# 5748               79802                INCIDENTE      RIO DE JANEIRO
# 5749               79756          INCIDENTE GRAVE           VICENTINA
# 5750               79844                INCIDENTE      RIO DE JANEIRO
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RJ                 ****     2010-01-03        12:00:00
# 1               PA                 SBBE     2010-01-03        11:05:00
# 2               RJ                 SBRJ     2010-01-03        03:00:00
# 3               MT                 ****     2010-01-04        17:30:00
# 4               RS                 SBPK     2010-01-05        19:25:00
# ...            ...                  ...            ...             ...
# 5747            TO                 ****     2020-12-30        18:30:00
# 5748            RJ                 SBGL     2020-12-30        00:54:00
# 5749            MS                 ****     2020-12-31        09:00:00
# 5750            RJ                 SBJR     2020-12-31        13:24:00
# 5751            RJ                 SBJR     2020-12-31        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                       0                    N�O
# 1                       0                    N�O
# 2                       0                    N�O
# 3                       0                    N�O
# 4                       0                    N�O
# ...                   ...                    ...
# 5747                    0                    N�O
# 5748                    0                    N�O
# 5749                    0                    N�O
# 5750                    0                    N�O
# 5751                    0                    N�O
#
# [5752 rows x 9 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BEL�M
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5746               79804                INCIDENTE            CAMPINAS
# 5747               79757          INCIDENTE GRAVE   LAGOA DA CONFUS�O
# 5748               79802                INCIDENTE      RIO DE JANEIRO
# 5749               79756          INCIDENTE GRAVE           VICENTINA
# 5750               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RJ                 ****     2010-01-03        12:00:00
# 1               PA                 SBBE     2010-01-03        11:05:00
# 2               RJ                 SBRJ     2010-01-03        03:00:00
# 3               MT                 ****     2010-01-04        17:30:00
# 4               RS                 SBPK     2010-01-05        19:25:00
# ...            ...                  ...            ...             ...
# 5746            SP                 SBKP     2020-12-29        19:00:00
# 5747            TO                 ****     2020-12-30        18:30:00
# 5748            RJ                 SBGL     2020-12-30        00:54:00
# 5749            MS                 ****     2020-12-31        09:00:00
# 5750            RJ                 SBJR     2020-12-31        13:24:00
#
#       total_recomendacoes ocorrencia_saida_pista
# 0                       0                    N�O
# 1                       0                    N�O
# 2                       0                    N�O
# 3                       0                    N�O
# 4                       0                    N�O
# ...                   ...                    ...
# 5746                    0                    N�O
# 5747                    0                    N�O
# 5748                    0                    N�O
# 5749                    0                    N�O
# 5750                    0                    N�O
#
# [5751 rows x 9 columns]
